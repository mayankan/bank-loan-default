# %%
#Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Load csv file using pandas
df = pd.read_csv("../data.csv")

# %%
df.head()
# Out:
#    age  ed  employ  address  income  debtinc   creddebt   othdebt  default
# 0   41   3      17       12     176      9.3  11.359392  5.008608      1.0
# 1   27   1      10        6      31     17.3   1.362202  4.000798      0.0
# 2   40   1      15       14      55      5.5   0.856075  2.168925      0.0
# 3   41   1      15       14     120      2.9   2.658720  0.821280      0.0
# 4   24   2       2        0      28     17.3   1.787436  3.056564      1.0

# %%
df.columns
# Out:
# Index(['age', 'ed', 'employ', 'address', 'income', 'debtinc', 'creddebt',
#        'othdebt', 'default'],
#       dtype='object')

# %% [markdown]
# ### 2) Exploratory Data Analysis
#
# Are there people applying more bank loan in a specific Education Category?
#
# Which Age Group or Income Group has more Loan Defaults?
#
# Does Higher Debt(debtinc, creddebt, otherdebt) results in Higher default chance?
#
# Do Lower Age Group(28-39) having more Bank Loans also have more deafults?
#
# Which Education Category does top 12 Age Group occurences have?

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 850 entries, 0 to 849
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       850 non-null    int64
#  1   ed        850 non-null    int64
#  2   employ    850 non-null    int64
#  3   address   850 non-null    int64
#  4   income    850 non-null    int64
#  5   debtinc   850 non-null    float64
#  6   creddebt  850 non-null    float64
#  7   othdebt   850 non-null    float64
#  8   default   700 non-null    float64
# dtypes: float64(4), int64(5)
# memory usage: 59.9 KB

# %%
df.describe()
# Out:
#               age          ed      employ     address      income     debtinc  \
# count  850.000000  850.000000  850.000000  850.000000  850.000000  850.000000
# mean    35.029412    1.710588    8.565882    8.371765   46.675294   10.171647
# std      8.041432    0.927784    6.777884    6.895016   38.543054    6.719441
# min     20.000000    1.000000    0.000000    0.000000   13.000000    0.100000
# 25%     29.000000    1.000000    3.000000    3.000000   24.000000    5.100000
# 50%     34.000000    1.000000    7.000000    7.000000   35.000000    8.700000
# 75%     41.000000    2.000000   13.000000   12.000000   55.750000   13.800000
# max     56.000000    5.000000   33.000000   34.000000  446.000000   41.300000
#
#          creddebt     othdebt     default
# count  850.000000  850.000000  700.000000
# mean     1.576805    3.078789    0.261429
# std      2.125840    3.398803    0.439727
# min      0.011696    0.045584    0.000000
# 25%      0.382176    1.045942    0.000000
# ...

# %%
df.isnull().sum()
# Out:
# age           0
# ed            0
# employ        0
# address       0
# income        0
# debtinc       0
# creddebt      0
# othdebt       0
# default     150
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Age

# %%
#Plotting histogram of age which is a numerical feature
plt.hist(df.age)
# Out:
# (array([ 49., 118., 119., 141., 104., 139.,  74.,  59.,  32.,  15.]),
#  array([20. , 23.6, 27.2, 30.8, 34.4, 38. , 41.6, 45.2, 48.8, 52.4, 56. ]),
#  <BarContainer object of 10 artists>)

# %%
#Plotting Distribution Plot of age which is a numerical feature
sns.distplot(df.age)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='age', ylabel='Density'>

# %%
#Plotting Comparision Distribution Plot of age and deafult differentiating defaulted and non-defaulted values of data
sns.distplot(df[df.default==1]['age'],color='r',label='Defaulted')
sns.distplot(df[df.default==0]['age'],color='g',label='Not Defaulted')
plt.legend()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ### Education

# %%
sns.barplot(x='ed',y='default',data=df)
# Out:
# <AxesSubplot:xlabel='ed', ylabel='default'>

# %%
sns.distplot(df.ed,bins=5)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='ed', ylabel='Density'>

# %%
sns.distplot(df[df.default==1]['ed'],color='r',label='Defaulted')
sns.distplot(df[df.default==0]['ed'],color='g',label='Not Defaulted')
plt.legend()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ### Employment Status

# %%
#Plotting histogram of employ which is a numerical feature
plt.hist(df.employ)
# Out:
# (array([231., 159., 135., 140.,  72.,  53.,  36.,  10.,   6.,   8.]),
#  array([ 0. ,  3.3,  6.6,  9.9, 13.2, 16.5, 19.8, 23.1, 26.4, 29.7, 33. ]),
#  <BarContainer object of 10 artists>)

# %%
#Plotting Distribution Plot of employ which is a numerical feature
sns.distplot(df.employ)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='employ', ylabel='Density'>

# %%
sns.distplot(df[df.default==1]['employ'],color='r',label='Defaulted')
sns.distplot(df[df.default==0]['employ'],color='g',label='Not Defaulted')
plt.legend()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ### Address

# %%
plt.hist(df.address)
# Out:
# (array([257., 151., 172.,  86.,  64.,  58.,  30.,  27.,   2.,   3.]),
#  array([ 0. ,  3.4,  6.8, 10.2, 13.6, 17. , 20.4, 23.8, 27.2, 30.6, 34. ]),
#  <BarContainer object of 10 artists>)

# %%
sns.distplot(df.address)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='address', ylabel='Density'>

# %%
sns.distplot(df[df.default==1]['address'],color='r',label='Defaulted')
sns.distplot(df[df.default==0]['address'],color='g',label='Not Defaulted')
plt.legend()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ### Income

# %%
plt.hist(df.income)
# Out:
# (array([644., 143.,  41.,  11.,   3.,   6.,   0.,   1.,   0.,   1.]),
#  array([ 13. ,  56.3,  99.6, 142.9, 186.2, 229.5, 272.8, 316.1, 359.4,
#         402.7, 446. ]),
#  <BarContainer object of 10 artists>)

# %%
sns.distplot(df.income)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='income', ylabel='Density'>

# %%
sns.distplot(df[df.default==1]['income'],color='r',label='Defaulted')
sns.distplot(df[df.default==0]['income'],color='g',label='Not Defaulted')
plt.legend()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ### Debt Income

# %%
plt.hist(df.debtinc)
# Out:
# (array([151., 255., 180., 129.,  71.,  32.,  18.,   9.,   4.,   1.]),
#  array([ 0.1 ,  4.22,  8.34, 12.46, 16.58, 20.7 , 24.82, 28.94, 33.06,
#         37.18, 41.3 ]),
#  <BarContainer object of 10 artists>)

# %%
sns.distplot(df.debtinc)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='debtinc', ylabel='Density'>

# %%
sns.distplot(df[df.default==1]['debtinc'],color='r',label='Defaulted')
sns.distplot(df[df.default==0]['debtinc'],color='g',label='Not Defaulted')
plt.legend()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ### Credit to Debt Ratio

# %%
plt.hist(df.creddebt)
# Out:
# (array([659., 120.,  40.,  16.,   6.,   2.,   2.,   4.,   0.,   1.]),
#  array([1.16960000e-02, 2.06665740e+00, 4.12161880e+00, 6.17658020e+00,
#         8.23154160e+00, 1.02865030e+01, 1.23414644e+01, 1.43964258e+01,
#         1.64513872e+01, 1.85063486e+01, 2.05613100e+01]),
#  <BarContainer object of 10 artists>)

# %%
sns.distplot(df.creddebt)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='creddebt', ylabel='Density'>

# %%
sns.distplot(df[df.default==1]['creddebt'],color='r',label='Defaulted')
sns.distplot(df[df.default==0]['creddebt'],color='g',label='Not Defaulted')
plt.legend()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
### Other Debt Income

# %%
plt.hist(df.othdebt)
# Out:
# (array([620., 144.,  54.,  16.,   9.,   4.,   1.,   1.,   0.,   1.]),
#  array([ 0.045584 ,  3.5607756,  7.0759672, 10.5911588, 14.1063504,
#         17.621542 , 21.1367336, 24.6519252, 28.1671168, 31.6823084,
#         35.1975   ]),
#  <BarContainer object of 10 artists>)

# %%
sns.distplot(df.othdebt)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='othdebt', ylabel='Density'>

# %%
sns.distplot(df[df.default==1]['othdebt'],color='r',label='Defaulted')
sns.distplot(df[df.default==0]['othdebt'],color='g',label='Not Defaulted')
plt.legend()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ### Default - Dependent Variable

# %%
sns.barplot(x='default',y='income',data=df)
# Out:
# <AxesSubplot:xlabel='default', ylabel='income'>

# %%
sns.barplot(x='default',y='ed',data=df)
# Out:
# <AxesSubplot:xlabel='default', ylabel='ed'>

# %%
sns.barplot(x='default',y='employ',data=df)
# Out:
# <AxesSubplot:xlabel='default', ylabel='employ'>

# %%
sns.barplot(x='default',y='address',data=df)
# Out:
# <AxesSubplot:xlabel='default', ylabel='address'>

# %%
sns.barplot(x='default',y='income',data=df)
# Out:
# <AxesSubplot:xlabel='default', ylabel='income'>

# %%
sns.barplot(x='default',y='debtinc',data=df)
# Out:
# <AxesSubplot:xlabel='default', ylabel='debtinc'>

# %%
sns.barplot(x='default',y='creddebt',data=df)
# Out:
# <AxesSubplot:xlabel='default', ylabel='creddebt'>

# %%
sns.barplot(x='default',y='othdebt',data=df)
# Out:
# <AxesSubplot:xlabel='default', ylabel='othdebt'>

# %%
sns.distplot(df.default,bins=5)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='default', ylabel='Density'>

# %% [markdown]
# ## Missing Values Analysis and Treatment

# %%
df.isnull().sum()
# Out:
# age           0
# ed            0
# employ        0
# address       0
# income        0
# debtinc       0
# creddebt      0
# othdebt       0
# default     150
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
null_indexes = df[df.default.isnull()].index
null_indexes
# Out:
# Int64Index([700, 701, 702, 703, 704, 705, 706, 707, 708, 709,
#             ...
#             840, 841, 842, 843, 844, 845, 846, 847, 848, 849],
#            dtype='int64', length=150)

# %%
df_nas = df.iloc[700:850,]
df_nas
# Out:
#      age  ed  employ  address  income  debtinc  creddebt   othdebt  default
# 700   36   1      16       13      32     10.9  0.544128  2.943872      NaN
# 701   50   1       6       27      21     12.9  1.316574  1.392426      NaN
# 702   40   1       9        9      33     17.0  4.880700  0.729300      NaN
# 703   31   1       5        7      23      2.0  0.046000  0.414000      NaN
# 704   29   1       4        0      24      7.8  0.866736  1.005264      NaN
# ..   ...  ..     ...      ...     ...      ...       ...       ...      ...
# 845   34   1      12       15      32      2.7  0.239328  0.624672      NaN
# 846   32   2      12       11     116      5.7  4.026708  2.585292      NaN
# 847   48   1      13       11      38     10.8  0.722304  3.381696      NaN
# 848   35   2       1       11      24      7.8  0.417456  1.454544      NaN
# 849   37   1      20       13      41     12.9  0.899130  4.389870      NaN
#
# [150 rows x 9 columns]

# %%
df = df.iloc[0:700]
df
# Out:
#      age  ed  employ  address  income  debtinc   creddebt   othdebt  default
# 0     41   3      17       12     176      9.3  11.359392  5.008608      1.0
# 1     27   1      10        6      31     17.3   1.362202  4.000798      0.0
# 2     40   1      15       14      55      5.5   0.856075  2.168925      0.0
# 3     41   1      15       14     120      2.9   2.658720  0.821280      0.0
# 4     24   2       2        0      28     17.3   1.787436  3.056564      1.0
# ..   ...  ..     ...      ...     ...      ...        ...       ...      ...
# 695   36   2       6       15      27      4.6   0.262062  0.979938      1.0
# 696   29   2       6        4      21     11.5   0.369495  2.045505      0.0
# 697   33   1      15        3      32      7.6   0.491264  1.940736      0.0
# 698   45   1      19       22      77      8.4   2.302608  4.165392      0.0
# 699   37   1      12       14      44     14.7   2.994684  3.473316      0.0
#
# [700 rows x 9 columns]

# %% [markdown]
# ## Outlier Analysis and Treatment

# %%
sns.boxplot(data=df)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Age

# %%
sns.boxplot(df.age)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='age'>

# %% [markdown]
# ### Education

# %%
df.ed.value_counts()
# Out:
# 1    372
# 2    198
# 3     87
# 4     38
# 5      5
# Name: ed, dtype: int64

# %%
sns.boxplot(df.ed)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='ed'>

# %%
Q1 = df.ed.describe()['25%']
Q3 = df.ed.describe()['75%']
IQR = Q3-Q1
print(Q1,IQR,Q3)
# Out:
# 1.0 1.0 2.0

# %%
sns.boxplot(df.ed[(df.ed<=5) & (df.ed>Q1-1.5*IQR)])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='ed'>

# %%
df.shape
# Out:
# (700, 9)

# %% [markdown]
# ### Employment Status

# %%
sns.boxplot(df.employ)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='employ'>

# %%
Q1 = df.employ.describe()['25%']
Q3 = df.employ.describe()['75%']
IQR = Q3-Q1
print(Q1,IQR,Q3)
# Out:
# 3.0 9.0 12.0

# %%
sns.boxplot(df.employ[(df.employ<Q3+1.5*IQR) & (df.employ>Q1-1.5*IQR)])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='employ'>

# %%
df = df[(df.employ<Q3+1.5*IQR) & (df.employ>Q1-1.5*IQR)]
df.shape
# Out:
# (690, 9)

# %% [markdown]
# ### Address

# %%
sns.boxplot(df.address)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='address'>

# %%
Q1 = df.address.describe()['25%']
Q3 = df.address.describe()['75%']
IQR = Q3-Q1
print(Q1,IQR,Q3)
# Out:
# 3.0 9.0 12.0

# %%
Q4 = df.employ.quantile(.69)
IQR = Q4-Q1
print(Q4,IQR)
# Out:
# 11.0 8.0

# %%
sns.boxplot(df.address[(df.address<Q4+1.5*IQR) & (df.address>Q1-1.5*IQR)])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='address'>

# %%
df = df[(df.address<Q4+1.5*IQR) & (df.address>Q1-1.5*IQR)]
df.shape
# Out:
# (658, 9)

# %% [markdown]
# ### Income

# %%
sns.boxplot(df.income)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='income'>

# %%
Q1 = df.income.describe()['25%']
Q3 = df.income.describe()['75%']
IQR = Q3-Q1
print(Q1,IQR,Q3)
# Out:
# 24.0 28.0 52.0

# %%
Q4 = df.income.quantile(.68)
IQR = Q4-Q1
print(Q4,IQR)
# Out:
# 44.0 20.0

# %%
sns.boxplot(df.income[(df.income<Q4+1.5*IQR) & (df.income>Q1-1.5*IQR)])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='income'>

# %%
df = df[(df.income<Q4+1.5*IQR) & (df.income>Q1-1.5*IQR)]
df.shape
# Out:
# (586, 9)

# %% [markdown]
# ### Debt Income

# %%
sns.boxplot(df.debtinc)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='debtinc'>

# %%
Q1 = df.debtinc.describe()['25%']
Q3 = df.debtinc.describe()['75%']
IQR = Q3-Q1
print(Q1,IQR,Q3)
# Out:
# 5.1 9.3 14.4

# %%
Q4 = df.debtinc.quantile(.73)
IQR = Q4-Q1
print(Q4,IQR)
# Out:
# 13.605 8.505

# %%
sns.boxplot(df.debtinc[(df.debtinc<Q4+1.5*IQR) & (df.debtinc>Q1-1.5*IQR)])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='debtinc'>

# %%
df = df[(df.debtinc<Q4+1.5*IQR) & (df.debtinc>Q1-1.5*IQR)]
df.shape
# Out:
# (570, 9)

# %% [markdown]
# ### Credit to Debt Ratio

# %%
sns.boxplot(df.creddebt)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='creddebt'>

# %%
Q1 = df.creddebt.describe()['25%']
Q3 = df.creddebt.describe()['75%']
IQR = Q3-Q1
print(Q1,IQR,Q3)
# Out:
# 0.31581 1.1802725000000003 1.4960825000000002

# %%
Q4 = df.creddebt.quantile(.67)
IQR = Q4-Q1
print(Q4,IQR)
# Out:
# 1.16842708 0.8526170800000001

# %%
sns.boxplot(df.creddebt[(df.creddebt<Q4+1.5*IQR) & (df.creddebt>Q1-1.5*IQR)])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='creddebt'>

# %%
df = df[(df.creddebt<Q4+1.5*IQR) & (df.creddebt>Q1-1.5*IQR)]
df.shape
# Out:
# (504, 9)

# %% [markdown]
# ### Other Debt Income

# %%
sns.boxplot(df.othdebt)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='othdebt'>

# %%
Q1 = df.othdebt.describe()['25%']
Q3 = df.othdebt.describe()['75%']
IQR = Q3-Q1
print(Q1,IQR,Q3)
# Out:
# 0.892653 1.6417964999999999 2.5344495

# %%
Q4 = df.othdebt.quantile(.69)
IQR = Q4-Q1
print(Q4,IQR)
# Out:
# 2.2154952999999997 1.3228422999999996

# %%
sns.boxplot(df.othdebt[(df.othdebt<Q4+1.5*IQR) & (df.othdebt>Q1-1.5*IQR)])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='othdebt'>

# %%
df = df[(df.othdebt<Q4+1.5*IQR) & (df.othdebt>Q1-1.5*IQR)]
df.shape
# Out:
# (459, 9)

# %% [markdown]
# ## Feature Engineering

# %%
df.corr()
# Out:
#                age        ed    employ   address    income   debtinc  \
# age       1.000000 -0.083346  0.362156  0.547655  0.423944 -0.102606
# ed       -0.083346  1.000000 -0.247178 -0.000717  0.122733 -0.042086
# employ    0.362156 -0.247178  1.000000  0.228200  0.565609 -0.296511
# address   0.547655 -0.000717  0.228200  1.000000  0.274376 -0.067033
# income    0.423944  0.122733  0.565609  0.274376  1.000000 -0.341943
# debtinc  -0.102606 -0.042086 -0.296511 -0.067033 -0.341943  1.000000
# creddebt  0.119389  0.062407  0.043491  0.118703  0.218030  0.531566
# othdebt   0.144968  0.032524  0.030767  0.072071  0.237100  0.689741
# default  -0.138208  0.083661 -0.362216 -0.186891 -0.236254  0.348148
#
#           creddebt   othdebt   default
# age       0.119389  0.144968 -0.138208
# ed        0.062407  0.032524  0.083661
# employ    0.043491  0.030767 -0.362216
# address   0.118703  0.072071 -0.186891
# income    0.218030  0.237100 -0.236254
# ...

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
plt.scatter(x=df.income,y=df.employ)

# %%
plt.scatter(x=df.debtinc,y=df.othdebt)

# %% [markdown]
# ## Feature Scaling

# %%
cnames = ['age', 'employ', 'address', 'income', 'debtinc', 'creddebt','othdebt']
cnames
# Out:
# ['age', 'employ', 'address', 'income', 'debtinc', 'creddebt', 'othdebt']

# %%
# Normalisation (val-min)/(max-min) - 0 to 1
for i in cnames:
    df[i] = (df[i] - min(df[i]))/(max(df[i]) - min(df[i]))
df.head()
# Out:
#         age  ed    employ   address    income   debtinc  creddebt   othdebt  \
# 1  0.200000   1  0.434783  0.272727  0.288136  0.649805  0.582132  0.959813
# 2  0.571429   1  0.652174  0.636364  0.694915  0.190661  0.363968  0.515272
# 4  0.114286   2  0.086957  0.000000  0.237288  0.649805  0.765429  0.730676
# 5  0.600000   2  0.217391  0.227273  0.186441  0.373541  0.164231  0.512451
# 7  0.657143   1  0.521739  0.500000  0.406780  0.116732  0.050388  0.289706
#
#    default
# 1      0.0
# 2      0.0
# 4      1.0
# 5      0.0
# 7      0.0

# %%
df.describe()
# Out:
#               age          ed      employ     address      income     debtinc  \
# count  459.000000  459.000000  459.000000  459.000000  459.000000  459.000000
# mean     0.351696    1.607843    0.261059    0.304912    0.283815    0.292109
# std      0.199661    0.863389    0.214947    0.248392    0.215517    0.195244
# min      0.000000    1.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.200000    1.000000    0.086957    0.090909    0.118644    0.151751
# 50%      0.314286    1.000000    0.217391    0.272727    0.220339    0.245136
# 75%      0.485714    2.000000    0.391304    0.454545    0.389831    0.391051
# max      1.000000    5.000000    1.000000    1.000000    1.000000    1.000000
#
#          creddebt     othdebt     default
# count  459.000000  459.000000  459.000000
# mean     0.301723    0.368279    0.239651
# std      0.245092    0.229130    0.427336
# min      0.000000    0.000000    0.000000
# 25%      0.113211    0.191393    0.000000
# ...

# %% [markdown]
# ## Handling Imbalanced Data (SMOTE)

# %%
df.default.value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
Defaulted = df[df.default==1]
Not_Defaulted = df[df.default==0]
print(Defaulted.shape,Not_Defaulted.shape)
# Out:
# (110, 9) (349, 9)

# %%
X=df[['age','ed','employ','address','income','debtinc','creddebt','othdebt']]
Y=df['default']

# %%
from imblearn.combine import SMOTETomek

# %%
smk = SMOTETomek(random_state=51)
X_res, y_res = smk.fit_sample(X,Y)

# %%
print(X_res.shape,y_res.shape)
# Out:
# (682, 8) (682,)

# %%
type(y_res)
# Out:
# pandas.core.series.Series

# %%
y_res.value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df = pd.concat([X_res,pd.DataFrame(y_res,columns=['default'])],axis=1)
df
# Out:
#           age  ed    employ   address    income   debtinc  creddebt   othdebt  \
# 0    0.200000   1  0.434783  0.272727  0.288136  0.649805  0.582132  0.959813
# 1    0.571429   1  0.652174  0.636364  0.694915  0.190661  0.363968  0.515272
# 2    0.114286   2  0.086957  0.000000  0.237288  0.649805  0.765429  0.730676
# 3    0.600000   2  0.217391  0.227273  0.186441  0.373541  0.164231  0.512451
# 4    0.657143   1  0.521739  0.500000  0.406780  0.116732  0.050388  0.289706
# ..        ...  ..       ...       ...       ...       ...       ...       ...
# 677  0.274350   2  0.000000  0.308886  0.161113  0.477428  0.449172  0.467085
# 678  0.477515   1  0.045558  0.134190  0.167870  0.566622  0.770051  0.431830
# 679  0.257213   2  0.086957  0.105986  0.169533  0.230882  0.089359  0.317006
# 680  0.257143   2  0.145416  0.225741  0.267632  0.220711  0.319140  0.262882
# 681  0.136760   1  0.017586  0.000000  0.047988  0.282647  0.283562  0.151346
#
#      default
# 0        0.0
# ...

# %% [markdown]
# # Predictive Modelling & Evaluation
# ## Insights from Data Preparation and EDA
#
# 1) None of the features of data is normally distributed.
#
# 2) Each of the feature is left skewed.
#
# 3) 150 rows out of total data of 850 rows has null values for dependent variable which were transferred to a new variable.
#
# 4) Most of the features have outliers which have been handled using IQR technique.
#
# 5) Income and Employment Status looked closely correlated but didn't show any positive correlation when plot on scatter plot.
#
# 6) Data for Loan Defaulters was imbalanced which is handled using SMOTE.

# %%
df.shape
# Out:
# (682, 9)

# %% [markdown]
# ## Multiple Logitic Regression

# %%
X=df[['age','ed','employ','address','income','debtinc','creddebt','othdebt']]
Y=df['default']

# %%
## Stratified Sampling
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.3, random_state=91, stratify=Y)

# %%
from sklearn.linear_model import LogisticRegression
logreg = LogisticRegression()

# %%
logreg.fit(X_train, y_train)
y_pred = logreg.predict(X_test)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.69      0.74      0.71       103
#          1.0       0.72      0.67      0.69       102
#
#     accuracy                           0.70       205
#    macro avg       0.70      0.70      0.70       205
# weighted avg       0.70      0.70      0.70       205

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix = confusion_matrix(y_test, y_pred)
print(confusion_matrix)
# Out:
# [[76 27]
#  [34 68]]

# %%
proba_pred = logreg.predict_proba(X_test)

# %%
# precision-recall curve and f1
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import f1_score
from sklearn.metrics import auc
from matplotlib import pyplot
# keep probabilities for the positive outcome only
lr_probs = proba_pred[:, 1]
# predict class values
lr_precision, lr_recall, _ = precision_recall_curve(y_test, lr_probs)
lr_f1, lr_auc = f1_score(y_test, y_pred), auc(lr_recall, lr_precision)
# summarize scores
print('Logistic: f1=%.3f auc=%.3f' % (lr_f1, lr_auc))
# plot the precision-recall curves
no_skill = len(y_test[y_test==1]) / len(y_test)
pyplot.plot([0, 1], [no_skill, no_skill], linestyle='--', label='No Skill')
pyplot.plot(lr_recall, lr_precision, marker='.', label='Logistic')
# axis labels
pyplot.xlabel('Recall')
pyplot.ylabel('Precision')
# show the legend
pyplot.legend()
# show the plot
pyplot.show()
# Out:
# Logistic: f1=0.690 auc=0.760

# %%
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
logit_roc_auc = roc_auc_score(y_test, y_pred)
fpr, tpr, thresholds = roc_curve(y_test, proba_pred[:,1])
plt.figure()
plt.plot(fpr, tpr, label='Logistic Regression (area = %0.2f)' % logit_roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.savefig('LogReg_ROC')
plt.show()

# %%
import matplotlib.pyplot as plt
import scikitplot as skplt
skplt.metrics.plot_cumulative_gain(y_test, proba_pred)
skplt.metrics.plot_lift_curve(y_test, proba_pred)
plt.show()

# %% [markdown]
# ## Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
clf_tree = DecisionTreeClassifier(criterion = 'gini', max_depth=3)

# %%
clf_tree.fit(X_train,y_train)
tree_predict = clf_tree.predict(X_test)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, tree_predict))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.75      0.68      0.71       103
#          1.0       0.71      0.77      0.74       102
#
#     accuracy                           0.73       205
#    macro avg       0.73      0.73      0.73       205
# weighted avg       0.73      0.73      0.73       205

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix = confusion_matrix(y_test, tree_predict)
print(confusion_matrix)
# Out:
# [[70 33]
#  [23 79]]

# %%
proba_pred = clf_tree.predict_proba(X_test)

# %%
# precision-recall curve and f1
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import f1_score
from sklearn.metrics import auc
from matplotlib import pyplot
# keep probabilities for the positive outcome only
lr_probs = proba_pred[:, 1]
# predict class values
lr_precision, lr_recall, _ = precision_recall_curve(y_test, lr_probs)
lr_f1, lr_auc = f1_score(y_test, y_pred), auc(lr_recall, lr_precision)
# summarize scores
print('Logistic: f1=%.3f auc=%.3f' % (lr_f1, lr_auc))
# plot the precision-recall curves
no_skill = len(y_test[y_test==1]) / len(y_test)
pyplot.plot([0, 1], [no_skill, no_skill], linestyle='--', label='No Skill')
pyplot.plot(lr_recall, lr_precision, marker='.', label='Logistic')
# axis labels
pyplot.xlabel('Recall')
pyplot.ylabel('Precision')
# show the legend
pyplot.legend()
# show the plot
pyplot.show()
# Out:
# Logistic: f1=0.690 auc=0.575

# %%
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
logit_roc_auc = roc_auc_score(y_test, tree_predict)
fpr, tpr, thresholds = roc_curve(y_test, proba_pred[:,1])
plt.figure()
plt.plot(fpr, tpr, label='Logistic Regression (area = %0.2f)' % logit_roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.savefig('DecisionTree_ROC')
plt.show()

# %%
import matplotlib.pyplot as plt
import scikitplot as skplt
skplt.metrics.plot_cumulative_gain(y_test, proba_pred)
skplt.metrics.plot_lift_curve(y_test, proba_pred)
plt.show()

# %% [markdown]
# ## K Nearest Neighbours

# %%
from sklearn.neighbors import KNeighborsClassifier
knn_clf = KNeighborsClassifier()

# %%
knn_clf.fit(X_train,y_train)
knn_predict = knn_clf.predict(X_test)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, knn_predict))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.86      0.67      0.75       103
#          1.0       0.73      0.89      0.80       102
#
#     accuracy                           0.78       205
#    macro avg       0.80      0.78      0.78       205
# weighted avg       0.80      0.78      0.78       205

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix = confusion_matrix(y_test, knn_predict)
print(confusion_matrix)
# Out:
# [[69 34]
#  [11 91]]

# %%
proba_pred = knn_clf.predict_proba(X_test)

# %%
# precision-recall curve and f1
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import f1_score
from sklearn.metrics import auc
from matplotlib import pyplot
# keep probabilities for the positive outcome only
lr_probs = proba_pred[:, 1]
# predict class values
lr_precision, lr_recall, _ = precision_recall_curve(y_test, lr_probs)
lr_f1, lr_auc = f1_score(y_test, y_pred), auc(lr_recall, lr_precision)
# summarize scores
print('Logistic: f1=%.3f auc=%.3f' % (lr_f1, lr_auc))
# plot the precision-recall curves
no_skill = len(y_test[y_test==1]) / len(y_test)
pyplot.plot([0, 1], [no_skill, no_skill], linestyle='--', label='No Skill')
pyplot.plot(lr_recall, lr_precision, marker='.', label='Logistic')
# axis labels
pyplot.xlabel('Recall')
pyplot.ylabel('Precision')
# show the legend
pyplot.legend()
# show the plot
pyplot.show()
# Out:
# Logistic: f1=0.690 auc=0.836

# %%
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
logit_roc_auc = roc_auc_score(y_test, knn_predict)
fpr, tpr, thresholds = roc_curve(y_test, proba_pred[:,1])
plt.figure()
plt.plot(fpr, tpr, label='Logistic Regression (area = %0.2f)' % logit_roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.savefig('KNN_ROC')
plt.show()

# %%
import matplotlib.pyplot as plt
import scikitplot as skplt
skplt.metrics.plot_cumulative_gain(y_test, proba_pred)
skplt.metrics.plot_lift_curve(y_test, proba_pred)
plt.show()

# %% [markdown]
# ## Gaussian Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()

# %%
gnb.fit(X_train,y_train)
gnb_predict = gnb.predict(X_test)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, gnb_predict))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.69      0.66      0.68       103
#          1.0       0.67      0.71      0.69       102
#
#     accuracy                           0.68       205
#    macro avg       0.68      0.68      0.68       205
# weighted avg       0.68      0.68      0.68       205

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix = confusion_matrix(y_test, gnb_predict)
print(confusion_matrix)
# Out:
# [[68 35]
#  [30 72]]

# %%
proba_pred = gnb.predict_proba(X_test)

# %%
# precision-recall curve and f1
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import f1_score
from sklearn.metrics import auc
from matplotlib import pyplot
# keep probabilities for the positive outcome only
lr_probs = proba_pred[:, 1]
# predict class values
lr_precision, lr_recall, _ = precision_recall_curve(y_test, lr_probs)
lr_f1, lr_auc = f1_score(y_test, y_pred), auc(lr_recall, lr_precision)
# summarize scores
print('Logistic: f1=%.3f auc=%.3f' % (lr_f1, lr_auc))
# plot the precision-recall curves
no_skill = len(y_test[y_test==1]) / len(y_test)
pyplot.plot([0, 1], [no_skill, no_skill], linestyle='--', label='No Skill')
pyplot.plot(lr_recall, lr_precision, marker='.', label='Logistic')
# axis labels
pyplot.xlabel('Recall')
pyplot.ylabel('Precision')
# show the legend
pyplot.legend()
# show the plot
pyplot.show()
# Out:
# Logistic: f1=0.690 auc=0.718

# %%
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
logit_roc_auc = roc_auc_score(y_test, gnb_predict)
fpr, tpr, thresholds = roc_curve(y_test, proba_pred[:,1])
plt.figure()
plt.plot(fpr, tpr, label='Logistic Regression (area = %0.2f)' % logit_roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.savefig('GNaiveBay_ROC')
plt.show()

# %%
import matplotlib.pyplot as plt
import scikitplot as skplt
skplt.metrics.plot_cumulative_gain(y_test, proba_pred)
skplt.metrics.plot_lift_curve(y_test, proba_pred)
plt.show()

# %% [markdown]
# ## Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
RF_model = RandomForestClassifier(max_depth = 100,n_estimators = 500).fit(X_train,y_train)
RF_pred = RF_model.predict(X_test)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, RF_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.80      0.80      0.80       103
#          1.0       0.79      0.79      0.79       102
#
#     accuracy                           0.80       205
#    macro avg       0.80      0.80      0.80       205
# weighted avg       0.80      0.80      0.80       205

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix = confusion_matrix(y_test, RF_pred)
print(confusion_matrix)
# Out:
# [[82 21]
#  [21 81]]

# %%
proba_pred = RF_model.predict_proba(X_test)

# %%
# precision-recall curve and f1
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import f1_score
from sklearn.metrics import auc
from matplotlib import pyplot
# keep probabilities for the positive outcome only
lr_probs = proba_pred[:, 1]
# predict class values
lr_precision, lr_recall, _ = precision_recall_curve(y_test, lr_probs)
lr_f1, lr_auc = f1_score(y_test, y_pred), auc(lr_recall, lr_precision)
# summarize scores
print('Logistic: f1=%.3f auc=%.3f' % (lr_f1, lr_auc))
# plot the precision-recall curves
no_skill = len(y_test[y_test==1]) / len(y_test)
pyplot.plot([0, 1], [no_skill, no_skill], linestyle='--', label='No Skill')
pyplot.plot(lr_recall, lr_precision, marker='.', label='Logistic')
# axis labels
pyplot.xlabel('Recall')
pyplot.ylabel('Precision')
# show the legend
pyplot.legend()
# show the plot
pyplot.show()
# Out:
# Logistic: f1=0.690 auc=0.888

# %%
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
logit_roc_auc = roc_auc_score(y_test, RF_pred)
fpr, tpr, thresholds = roc_curve(y_test, proba_pred[:,1])
plt.figure()
plt.plot(fpr, tpr, label='Logistic Regression (area = %0.2f)' % logit_roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.savefig('RandomFor_ROC')
plt.show()

# %%
import matplotlib.pyplot as plt
import scikitplot as skplt
skplt.metrics.plot_cumulative_gain(y_test, proba_pred)
skplt.metrics.plot_lift_curve(y_test, proba_pred)
plt.show()

# %% [markdown]
# ## AdaBoost

# %%
from sklearn.ensemble import AdaBoostClassifier
logref_clf = LogisticRegression()

# %%
ada_clf = AdaBoostClassifier(logref_clf,n_estimators=50).fit(X_train,y_train)
ada_pred = ada_clf.predict(X_test)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, RF_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.80      0.80      0.80       103
#          1.0       0.79      0.79      0.79       102
#
#     accuracy                           0.80       205
#    macro avg       0.80      0.80      0.80       205
# weighted avg       0.80      0.80      0.80       205

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix = confusion_matrix(y_test, RF_pred)
print(confusion_matrix)
# Out:
# [[82 21]
#  [21 81]]

# %%
proba_pred = ada_clf.predict_proba(X_test)

# %%
# precision-recall curve and f1
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import f1_score
from sklearn.metrics import auc
from matplotlib import pyplot
# keep probabilities for the positive outcome only
lr_probs = proba_pred[:, 1]
# predict class values
lr_precision, lr_recall, _ = precision_recall_curve(y_test, lr_probs)
lr_f1, lr_auc = f1_score(y_test, y_pred), auc(lr_recall, lr_precision)
# summarize scores
print('Logistic: f1=%.3f auc=%.3f' % (lr_f1, lr_auc))
# plot the precision-recall curves
no_skill = len(y_test[y_test==1]) / len(y_test)
pyplot.plot([0, 1], [no_skill, no_skill], linestyle='--', label='No Skill')
pyplot.plot(lr_recall, lr_precision, marker='.', label='Logistic')
# axis labels
pyplot.xlabel('Recall')
pyplot.ylabel('Precision')
# show the legend
pyplot.legend()
# show the plot
pyplot.show()
# Out:
# Logistic: f1=0.690 auc=0.748

# %%
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
logit_roc_auc = roc_auc_score(y_test, ada_pred)
fpr, tpr, thresholds = roc_curve(y_test, proba_pred[:,1])
plt.figure()
plt.plot(fpr, tpr, label='Logistic Regression (area = %0.2f)' % logit_roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.savefig('AdaBoost_ROC')
plt.show()

# %%
import matplotlib.pyplot as plt
import scikitplot as skplt
skplt.metrics.plot_cumulative_gain(y_test, proba_pred)
skplt.metrics.plot_lift_curve(y_test, proba_pred)
plt.show()

# %% [markdown]
# ## Gradient Boosting

# %%
from sklearn.ensemble import GradientBoostingClassifier
gboost_clf = GradientBoostingClassifier(n_estimators=500,max_depth=10)

# %%
gboost_clf.fit(X_train,y_train)
gboost_pred = gboost_clf.predict(X_test)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, gboost_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.76      0.82      0.79       103
#          1.0       0.80      0.74      0.77       102
#
#     accuracy                           0.78       205
#    macro avg       0.78      0.78      0.78       205
# weighted avg       0.78      0.78      0.78       205

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix = confusion_matrix(y_test, gboost_pred)
print(confusion_matrix)
# Out:
# [[84 19]
#  [27 75]]

# %%
proba_pred = gboost_clf.predict_proba(X_test)

# %%
# precision-recall curve and f1
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import f1_score
from sklearn.metrics import auc
from matplotlib import pyplot
# keep probabilities for the positive outcome only
lr_probs = proba_pred[:, 1]
# predict class values
lr_precision, lr_recall, _ = precision_recall_curve(y_test, lr_probs)
lr_f1, lr_auc = f1_score(y_test, y_pred), auc(lr_recall, lr_precision)
# summarize scores
print('Logistic: f1=%.3f auc=%.3f' % (lr_f1, lr_auc))
# plot the precision-recall curves
no_skill = len(y_test[y_test==1]) / len(y_test)
pyplot.plot([0, 1], [no_skill, no_skill], linestyle='--', label='No Skill')
pyplot.plot(lr_recall, lr_precision, marker='.', label='Logistic')
# axis labels
pyplot.xlabel('Recall')
pyplot.ylabel('Precision')
# show the legend
pyplot.legend()
# show the plot
pyplot.show()
# Out:
# Logistic: f1=0.690 auc=0.895

# %%
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
logit_roc_auc = roc_auc_score(y_test, gboost_pred)
fpr, tpr, thresholds = roc_curve(y_test, proba_pred[:,1])
plt.figure()
plt.plot(fpr, tpr, label='Logistic Regression (area = %0.2f)' % logit_roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.savefig('GradBoost_ROC')
plt.show()

# %%
import matplotlib.pyplot as plt
import scikitplot as skplt
skplt.metrics.plot_cumulative_gain(y_test, proba_pred)
skplt.metrics.plot_lift_curve(y_test, proba_pred)
plt.show()

# %% [markdown]
# ## Stochastic Gradient Descent

# %%
from sklearn.linear_model import SGDClassifier
SGD_clf = SGDClassifier(loss="hinge", penalty="l2", max_iter=5)

# %%
SGD_clf.fit(X_train, y_train)
SGD_pred = SGD_clf.predict(X_test)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/sklearn/linear_model/_stochastic_gradient.py:570: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn("Maximum number of iteration reached before "

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, SGD_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.54      0.95      0.69       103
#          1.0       0.79      0.19      0.30       102
#
#     accuracy                           0.57       205
#    macro avg       0.67      0.57      0.50       205
# weighted avg       0.67      0.57      0.50       205

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix = confusion_matrix(y_test, SGD_pred)
print(confusion_matrix)
# Out:
# [[98  5]
#  [83 19]]

# %%
#calibrator = CalibratedClassifierCV(SGD_fit, cv='prefit')
proba_pred = SGD_clf.decision_function(X_test)

# %%
# precision-recall curve and f1
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import f1_score
from sklearn.metrics import auc
from matplotlib import pyplot
# keep probabilities for the positive outcome only
lr_probs = proba_pred
# predict class values
lr_precision, lr_recall, _ = precision_recall_curve(y_test, lr_probs)
lr_f1, lr_auc = f1_score(y_test, y_pred), auc(lr_recall, lr_precision)
# summarize scores
print('Logistic: f1=%.3f auc=%.3f' % (lr_f1, lr_auc))
# plot the precision-recall curves
no_skill = len(y_test[y_test==1]) / len(y_test)
pyplot.plot([0, 1], [no_skill, no_skill], linestyle='--', label='No Skill')
pyplot.plot(lr_recall, lr_precision, marker='.', label='Logistic')
# axis labels
pyplot.xlabel('Recall')
pyplot.ylabel('Precision')
# show the legend
pyplot.legend()
# show the plot
pyplot.show()
# Out:
# Logistic: f1=0.690 auc=0.730

# %%
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
logit_roc_auc = roc_auc_score(y_test, SGD_pred)
fpr, tpr, thresholds = roc_curve(y_test, proba_pred)
plt.figure()
plt.plot(fpr, tpr, label='Logistic Regression (area = %0.2f)' % logit_roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.savefig('SGD_ROC')
plt.show()

# %% [markdown]
# ## Support Vector Machine

# %%
from sklearn.svm import SVC
svc = SVC(kernel='linear',probability=True)

# %%
svc.fit(X_train,y_train)
svc_predict = svc.predict(X_test)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, svc_predict))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.80      0.72      0.76       103
#          1.0       0.74      0.82      0.78       102
#
#     accuracy                           0.77       205
#    macro avg       0.77      0.77      0.77       205
# weighted avg       0.77      0.77      0.77       205

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix = confusion_matrix(y_test, svc_predict)
print(confusion_matrix)
# Out:
# [[74 29]
#  [18 84]]

# %%
proba_pred = svc.predict_proba(X_test)

# %%
# precision-recall curve and f1
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import f1_score
from sklearn.metrics import auc
from matplotlib import pyplot
# keep probabilities for the positive outcome only
lr_probs = proba_pred[:, 1]
# predict class values
lr_precision, lr_recall, _ = precision_recall_curve(y_test, lr_probs)
lr_f1, lr_auc = f1_score(y_test, y_pred), auc(lr_recall, lr_precision)
# summarize scores
print('Logistic: f1=%.3f auc=%.3f' % (lr_f1, lr_auc))
# plot the precision-recall curves
no_skill = len(y_test[y_test==1]) / len(y_test)
pyplot.plot([0, 1], [no_skill, no_skill], linestyle='--', label='No Skill')
pyplot.plot(lr_recall, lr_precision, marker='.', label='Logistic')
# axis labels
pyplot.xlabel('Recall')
pyplot.ylabel('Precision')
# show the legend
pyplot.legend()
# show the plot
pyplot.show()
# Out:
# Logistic: f1=0.690 auc=0.780

# %%
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
logit_roc_auc = roc_auc_score(y_test, svc_predict)
fpr, tpr, thresholds = roc_curve(y_test, proba_pred[:,1])
plt.figure()
plt.plot(fpr, tpr, label='Logistic Regression (area = %0.2f)' % logit_roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.savefig('SVM_ROC')
plt.show()

# %%
import matplotlib.pyplot as plt
import scikitplot as skplt
skplt.metrics.plot_cumulative_gain(y_test, proba_pred)
skplt.metrics.plot_lift_curve(y_test, proba_pred)
plt.show()

# %% [markdown]
# ## Artificial Neural Network

# %%
import tensorflow as tf
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense

# %%
# Define the keras model
model = Sequential()
model.add(Dense(12, input_dim=8, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
# compile the keras model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# fit the keras model on the dataset
model.fit(X_train, y_train, epochs=150, batch_size=10)
# Out:
# Epoch 1/150
# 48/48 [==============================] - 0s 2ms/step - loss: 0.6919 - accuracy: 0.5514
# Epoch 2/150
# 48/48 [==============================] - 0s 2ms/step - loss: 0.6879 - accuracy: 0.5870
# Epoch 3/150
# 48/48 [==============================] - 0s 2ms/step - loss: 0.6844 - accuracy: 0.6289
# Epoch 4/150
# 48/48 [==============================] - 0s 2ms/step - loss: 0.6793 - accuracy: 0.6289
# Epoch 5/150
# 48/48 [==============================] - 0s 2ms/step - loss: 0.6737 - accuracy: 0.6415
# Epoch 6/150
# 48/48 [==============================] - 0s 2ms/step - loss: 0.6676 - accuracy: 0.6520
# Epoch 7/150
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6610 - accuracy: 0.6583
# Epoch 8/150
# 48/48 [==============================] - 0s 2ms/step - loss: 0.6534 - accuracy: 0.6771
# Epoch 9/150
# 48/48 [==============================] - 0s 2ms/step - loss: 0.6372 - accuracy: 0.7023
# Epoch 10/150
# ...

# %% [markdown]
# # Summary and Conclusion
# ##

# %% [markdown]
# ## From all the algorithms I executed and evaluated manually, Random Forest and Ada Boosting had the same Accuracy and Recall.
# ## So, they both are the models which can be used to predict most of the default cases trained on this dataset.
